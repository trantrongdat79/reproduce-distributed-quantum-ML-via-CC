# %%
from DQML import Run
import pickle

with open('./Dataset/Dataset1', 'rb') as f:
    X=pickle.load(f)
Run.run_DQML('CCDQML',3,X,1,100)

#run_DQML(scheme,depth,dataset,repetition of whole training process,training_iteration)
#DQML Scheme ('non_DQML','QCDQML_1m','QCDQML_nonbiased','QCDQML,'CCDQML','NCDQML')
#QCDQML_nonbiased: single measure QCDQML_1m: single measure with bias QCDQML: double measure with bias
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 6
#       2 import pickle
#       3
#       4 with open('./Dataset/Dataset1', 'rb') as f:
#       5     X=pickle.load(f)
# ----> 6 Run.run_DQML('CCDQML',3,X,1,100)
#       7
#       8 #run_DQML(scheme,depth,dataset,repetition of whole training process,training_iteration)
#       9 #DQML Scheme ('non_DQML','QCDQML_1m','QCDQML_nonbiased','QCDQML,'CCDQML','NCDQML')
#
# File ~/Data/quantum/reproduce-distributed-quantum-ML-via-CC/DQML/DQML/Run.py:10, in run_DQML(scheme, depth, X, iter, iter_train, iter_start)
#       7 def run_DQML(scheme,depth,X,iter,iter_train,iter_start=0):
#       9     for i in range(iter_start,iter_start+iter):
# ---> 10         C,A,W,B=DQML(scheme,depth,iter_train,X)
#      11         Result=[C,A,W,B]
#      12         with open(scheme+'_'+'depth'+str(depth)+'_'+str(i+1), 'wb') as f:
#
# File ~/Data/quantum/reproduce-distributed-quantum-ML-via-CC/DQML/DQML/Machine.py:73, in DQML(scheme, depth, iteration, train_validation_set)
#      69     acc_val = accuracy(Y_val, predictions_val)
#      72 elif scheme=='NCDQML' or scheme== 'CCDQML' or scheme== 'QCDQML':
# ---> 73     opt_result = opt.step_and_cost(cost,weights,bias,feats_train_batch, Y_train_batch)
#      74     weights,bias,_,_=opt_result[0]
#      75     predictions_val=[]
#
# File ~/Data/quantum/reproduce-distributed-quantum-ML-via-CC/.venv/lib/python3.12/site-packages/pennylane/optimize/gradient_descent.py:64, in GradientDescentOptimizer.step_and_cost(self, objective_fn, grad_fn, *args, **kwargs)
#      44 def step_and_cost(self, objective_fn, *args, grad_fn=None, **kwargs):
#      45     """Update trainable arguments with one step of the optimizer and return the corresponding
#      46     objective function value prior to the step.
#      47
#    (...)     61         If single arg is provided, list [array] is replaced by array.
#      62     """
# ---> 64     g, forward = self.compute_grad(objective_fn, args, kwargs, grad_fn=grad_fn)
#      65     new_args = self.apply_grad(g, args)
#      67     if forward is None:
#
# File ~/Data/quantum/reproduce-distributed-quantum-ML-via-CC/.venv/lib/python3.12/site-packages/pennylane/optimize/gradient_descent.py:122, in GradientDescentOptimizer.compute_grad(objective_fn, args, kwargs, grad_fn)
#     104 r"""Compute the gradient of the objective function at the given point and return it along with
#     105 the objective function forward pass (if available).
#     106
#    (...)    119     will not be evaluated and instead ``None`` will be returned.
#     120 """
#     121 g = get_gradient(objective_fn) if grad_fn is None else grad_fn
# --> 122 grad = g(*args, **kwargs)
#     123 forward = getattr(g, "forward", None)
#     125 num_trainable_args = sum(getattr(arg, "requires_grad", False) for arg in args)
#
# File ~/Data/quantum/reproduce-distributed-quantum-ML-via-CC/.venv/lib/python3.12/site-packages/pennylane/_grad/grad.py:369, in grad.__call__(self, *args, **kwargs)
#     366 if self._h:
#     367     raise ValueError(f"h = {self._h} unsupported without QJIT. Must be ``None``.")
# --> 369 return self._autograd_call(*args, **kwargs)
#
# File ~/Data/quantum/reproduce-distributed-quantum-ML-via-CC/.venv/lib/python3.12/site-packages/pennylane/_grad/grad.py:374, in grad._autograd_call(self, *args, **kwargs)
#     371 def _autograd_call(self, *args, **kwargs):
#     372     """Evaluates the gradient function, and saves the function value
#     373     calculated during the forward pass in :attr:`.forward`."""
# --> 374     grad_fn, argnum = self._get_grad_fn(args)
#     376     if not isinstance(argnum, int) and not argnum:
#     377         warnings.warn(
#     378             "Attempted to differentiate a function with no trainable parameters. "
#     379             "If this is unintended, please add trainable parameters via the "
#     380             "'requires_grad' attribute or 'argnums' keyword."
#     381         )
#
# File ~/Data/quantum/reproduce-distributed-quantum-ML-via-CC/.venv/lib/python3.12/site-packages/pennylane/_grad/grad.py:341, in grad._get_grad_fn(self, args)
#     339     if trainable:
#     340         if arg.dtype.name[:3] == "int":
# --> 341             raise ValueError("Autograd does not support differentiation of ints.")
#     342         argnums.append(idx)
#     344 if len(argnums) == 1:
#
# ValueError: Autograd does not support differentiation of ints.

# %%
#Effective Diemsnion

Run.run_ED('CCDQML4',[2],20,20)

#run_ED(scheme,depth_list,it,x_sample)
#Scheme : NCDQML4 CCDQML4 QCDQML4 NCDQML8 CCDQML8 QCDQML8
