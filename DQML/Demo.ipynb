# %%
from DQML import Run
import pickle

with open('./Dataset/Dataset1', 'rb') as f:
    X=pickle.load(f)
Run.run_DQML('CCDQML',3,X,1,100)

#run_DQML(scheme,depth,dataset,repetition of whole training process,training_iteration)
#DQML Scheme ('non_DQML','QCDQML_1m','QCDQML_nonbiased','QCDQML,'CCDQML','NCDQML')
#QCDQML_nonbiased: single measure QCDQML_1m: single measure with bias QCDQML: double measure with bias
# Out:
# ( 0 ) loss: 1.01 accuracy: 0.55
# ( 10 ) loss: 0.97 accuracy: 0.6
# ( 20 ) loss: 0.96 accuracy: 0.68
# ( 30 ) loss: 0.93 accuracy: 0.68
# ( 40 ) loss: 0.93 accuracy: 0.7
# ( 50 ) loss: 0.92 accuracy: 0.69
# ( 60 ) loss: 0.91 accuracy: 0.72
# ( 70 ) loss: 0.89 accuracy: 0.74
# ( 80 ) loss: 0.9 accuracy: 0.71
# ( 90 ) loss: 0.87 accuracy: 0.73
# ---final---
# loss: 0.85 accuracy: 0.74
# 74.5 mins
# bias: [ 1.61671288 -1.48412087 -1.49273887  1.44491976]

# %%
#Effective Diemsnion
from DQML import Run
import pickle

Run.run_ED('CCDQML4',[2],20,20)

#run_ED(scheme,depth_list,it,x_sample)
#Scheme : NCDQML4 CCDQML4 QCDQML4 NCDQML8 CCDQML8 QCDQML8
# Out:
# iter 1 done in 0.6 sec
# iter 11 done in 5.7 sec
# depth 2 done in 10.2 sec
